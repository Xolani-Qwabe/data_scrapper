# %%
import pandas as pd

# %%
stats_df = pd.read_csv('premier_league_stats.csv')
stats_df.head(20)
# Out:
#     Rk            Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1          Arsenal   7  5  1  1  14   3  11   16    2.29  11.9   4.3
# 1    2        Liverpool   7  5  0  2  13   9   4   15    2.14  10.9   7.9
# 2    3        Tottenham   7  4  2  1  13   5   8   14    2.00   7.4   8.7
# 3    4      Bournemouth   7  4  2  1  11   8   3   14    2.00   8.4   6.3
# 4    5  Manchester City   7  4  1  2  15   6   9   13    1.86  12.1   7.1
# 5    6   Crystal Palace   7  3  3  1   9   5   4   12    1.71  12.7   8.7
# 6    7          Chelsea   7  3  2  2  13   9   4   11    1.57  10.9   9.7
# 7    8          Everton   7  3  2  2   9   7   2   11    1.57   9.7   9.5
# 8    9       Sunderland   7  3  2  2   7   6   1   11    1.57   6.7   8.7
# 9   10   Manchester Utd   7  3  1  3   9  11  -2   10    1.43  13.6   9.9
# 10  11    Newcastle Utd   7  2  3  2   6   5   1    9    1.29   8.4   4.7
# 11  12         Brighton   7  2  3  2  10  10   0    9    1.29  11.2   9.1
# ...
